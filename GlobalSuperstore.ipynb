# %%
import pandas as pd

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\Prime\Downloads

# %%
df = pd.read_csv("C:/Users/Prime/OneDrive/Documents/Excel data/Global Superstore.csv", encoding='latin1')

# %%
print(df.shape)
# Out:
# (51290, 24)

# %%
print(df.columns)
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country',
#        'Postal Code', 'Market', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
# read csv file
df = pd.read_csv(r"C:\Users\Prime\OneDrive\Documents\Excel data\Global Superstore.csv", encoding='latin1')

# %%
 display(df.head())
# Out:
#    Row ID         Order ID  Order Date   Ship Date     Ship Mode Customer ID  \
# 0   32298   CA-2012-124891  31-07-2012  31-07-2012      Same Day    RH-19495
# 1   26341    IN-2013-77878  05-02-2013  07-02-2013  Second Class    JR-16210
# 2   25330    IN-2013-71249  17-10-2013  18-10-2013   First Class    CR-12730
# 3   13524  ES-2013-1579342  28-01-2013  30-01-2013   First Class    KM-16375
# 4   47221     SG-2013-4320  05-11-2013  06-11-2013      Same Day     RH-9495
#
#       Customer Name      Segment           City            State  ...  \
# 0       Rick Hansen     Consumer  New York City         New York  ...
# 1     Justin Ritter    Corporate     Wollongong  New South Wales  ...
# 2      Craig Reiter     Consumer       Brisbane       Queensland  ...
# 3  Katherine Murray  Home Office         Berlin           Berlin  ...
# 4       Rick Hansen     Consumer          Dakar            Dakar  ...
#
#          Product ID    Category Sub-Category  \
# ...

# %%
# data types
df.dtypes
# Out:
# Row ID              int64
# Order ID           object
# Order Date         object
# Ship Date          object
# Ship Mode          object
# Customer ID        object
# Customer Name      object
# Segment            object
# City               object
# State              object
# Country            object
# Postal Code       float64
# Market             object
# Region             object
# Product ID         object
# Category           object
# Sub-Category       object
# Product Name       object
# Sales             float64
# Quantity            int64
# Discount          float64
# Profit            float64
# Shipping Cost     float64
# Order Priority     object
# dtype: object

# %%
# number of row missing
df.isnull()
# Out:
#        Row ID  Order ID  Order Date  Ship Date  Ship Mode  Customer ID  \
# 0       False     False       False      False      False        False
# 1       False     False       False      False      False        False
# 2       False     False       False      False      False        False
# 3       False     False       False      False      False        False
# 4       False     False       False      False      False        False
# ...       ...       ...         ...        ...        ...          ...
# 51285   False     False       False      False      False        False
# 51286   False     False       False      False      False        False
# 51287   False     False       False      False      False        False
# 51288   False     False       False      False      False        False
# 51289   False     False       False      False      False        False
#
#        Customer Name  Segment   City  State  ...  Product ID  Category  \
# ...

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country',
#        'Postal Code', 'Market', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
# drop cloumn
df.drop('State',axis = 1)
# Out:
#        Row ID         Order ID  Order Date   Ship Date       Ship Mode  \
# 0       32298   CA-2012-124891  31-07-2012  31-07-2012        Same Day
# 1       26341    IN-2013-77878  05-02-2013  07-02-2013    Second Class
# 2       25330    IN-2013-71249  17-10-2013  18-10-2013     First Class
# 3       13524  ES-2013-1579342  28-01-2013  30-01-2013     First Class
# 4       47221     SG-2013-4320  05-11-2013  06-11-2013        Same Day
# ...       ...              ...         ...         ...             ...
# 51285   29002    IN-2014-62366  19-06-2014  19-06-2014        Same Day
# 51286   35398   US-2014-102288  20-06-2014  24-06-2014  Standard Class
# 51287   40470   US-2013-155768  02-12-2013  02-12-2013        Same Day
# 51288    9596   MX-2012-140767  18-02-2012  22-02-2012  Standard Class
# 51289    6147   MX-2012-134460  22-05-2012  26-05-2012    Second Class
#
#       Customer ID     Customer Name      Segment           City  \
# ...

# %%
df = pd.read_csv("C:/Users/Prime/OneDrive/Documents/Excel data/People.csv", encoding='latin1')

# %%
print(df.shape)
# Out:
# (13, 2)

# %%
print(df.columns)
# Out:
# Index(['Person', 'Region'], dtype='object')

# %%
df = pd.read_csv(r"C:\Users\Prime\OneDrive\Documents\Excel data\People.csv", encoding='latin1')

# %%
 display(df.head())
# Out:
#               Person   Region
# 0      Anna Andreadi  Central
# 1        Chuck Magee    South
# 2     Kelly Williams     East
# 3     Matt Collister     West
# 4  Deborah Brumfield   Africa

# %%
# data types
df.dtypes
# Out:
# Person    object
# Region    object
# dtype: object

# %%
# number of row missing
df.isnull()
# Out:
#     Person  Region
# 0    False   False
# 1    False   False
# 2    False   False
# 3    False   False
# 4    False   False
# 5    False   False
# 6    False   False
# 7    False   False
# 8    False   False
# 9    False   False
# 10   False   False
# 11   False   False
# 12   False   False

# %%
df = pd.read_csv("C:/Users/Prime/OneDrive/Documents/Excel data/return.csv", encoding='latin1')

# %%
print(df.shape)
# Out:
# (1173, 3)

# %%
print(df.columns)
# Out:
# Index(['ï»¿Returned', 'Order ID', 'Market'], dtype='object')

# %%
df = pd.read_csv(r"C:\Users\Prime\OneDrive\Documents\Excel data\return.csv", encoding='latin1')

# %%
 display(df.head())
# Out:
#   ï»¿Returned         Order ID         Market
# 0         Yes   MX-2013-168137          LATAM
# 1         Yes   US-2011-165316          LATAM
# 2         Yes  ES-2013-1525878             EU
# 3         Yes   CA-2013-118311  United States
# 4         Yes  ES-2011-1276768             EU

# %%
# data types
df.dtypes
# Out:
# ï»¿Returned    object
# Order ID       object
# Market         object
# dtype: object

# %%
# number of row missing
df.isnull()
# Out:
#       ï»¿Returned  Order ID  Market
# 0           False     False   False
# 1           False     False   False
# 2           False     False   False
# 3           False     False   False
# 4           False     False   False
# ...           ...       ...     ...
# 1168        False     False   False
# 1169        False     False   False
# 1170        False     False   False
# 1171        False     False   False
# 1172        False     False   False
#
# [1173 rows x 3 columns]
